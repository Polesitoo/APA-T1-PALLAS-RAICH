# %%
import numpy as np
import matplotlib.pyplot as plt
import soundfile as sf
import sounddevice as sd
from numpy.fft import fft

# %% [markdown]
# # Apartado 1

# %% [markdown]
# ## 4 kHz

# %%
T= 2.5                                    # Durada de T segons
fm=80000                                  # Freqüència de mostratge en Hz
fx=4000                                   # Freqüència de la sinusoide
A=4                                       # Amplitud de la sinusoide
pi=np.pi                                  # Valor del número pi
L = int(fm * T)                           # Nombre de mostres del senyal digital
Tm=1/fm                                   # Període de mostratge
t=Tm*np.arange(L)                         # Vector amb els valors de la variable temporal, de 0 a T
x = A * np.cos(2 * pi * fx * t)           # Senyal sinusoidal
sf.write('wav/so_4000.wav', x, fm)        # Escriptura del senyal a un fitxer en format wav
Tx=1/fx                                   # Període del senyal
Ls=int(fm*5*Tx)                           # Nombre de mostres corresponents a 5 períodes de la sinusoide
plt.figure(0)                             # Nova figura
plt.plot(t[0:Ls], x[0:Ls])                # Representació del senyal en funció del temps
plt.xlabel('t en segons')                 # Etiqueta eix temporal
plt.title('5 periodes de la sinusoide')   # Títol del gràfic
#sd.play(x, fm)                            # Reproducció d'àudio
plt.savefig('img/sinusoide_4kHz.png')     # Escriptura de la gràfica del senyal en un fitxer png
plt.show()

# %% [markdown]
# ## 5 kHz

# %%
fm=80000                                  # Freqüència de mostratge en Hz
fx=5000                                   # Freqüència de la sinusoide                                    
L = int(fm * T)                           # Nombre de mostres del senyal digital
Tm=1/fm                                   # Període de mostratge
t=Tm*np.arange(L)                         # Vector amb els valors de la variable temporal, de 0 a T
x1 = A * np.cos(2 * pi * fx * t)          # Senyal sinusoidal
sf.write('so_5000.wav', x1, fm)           # Escriptura del senyal a un fitxer en format wav
Tx=1/fx                                   # Període del senyal
Ls=int(fm*5*Tx)                           # Nombre de mostres corresponents a 5 períodes de la sinusoide
plt.figure(1)                             # Nova figura
plt.plot(t[0:Ls], x1[0:Ls])               # Representació del senyal en funció del temps
plt.xlabel('t en segons')                 # Etiqueta eix temporal
plt.title('5 periodes de la sinusoide')   # Títol del gràfic
#sd.play(x1, fm)                           # Reproducció d'àudio
plt.savefig('img/sinusoide_5kHz.png')     # Escriptura de la gràfica del senyal en un fitxer png
plt.show()

# %% [markdown]
# ## 6 kHz

# %%
fm=300000                                 # Freqüència de mostratge en Hz
fx=6000                                   # Freqüència de la sinusoide
L = int(fm * T)                           # Nombre de mostres del senyal digital
Tm=1/fm                                   # Període de mostratge
t=Tm*np.arange(L)                         # Vector amb els valors de la variable temporal, de 0 a T
x2 = A * np.cos(2 * pi * fx * t)           # Senyal sinusoidal
sf.write('so_6000.wav', x2, fm)            # Escriptura del senyal a un fitxer en format wav
Tx=1/fx                                   # Període del senyal
Ls=int(fm*5*Tx)                           # Nombre de mostres corresponents a 5 períodes de la sinusoide
plt.figure(2)                             # Nova figura
plt.plot(t[0:Ls], x2[0:Ls])                # Representació del senyal en funció del temps
plt.xlabel('t en segons')                 # Etiqueta eix temporal
plt.title('5 periodes de la sinusoide')   # Títol del gràfic
#sd.play(x2, fm)                            # Reproducció d'àudio
plt.savefig('img/sinusoide_6kHz.png')     # Escriptura de la gràfica del senyal en un fitxer png
plt.show()

# %% [markdown]
# ## 10 kHz

# %%
fm=200000                                 # Freqüència de mostratge en Hz
fx=10000                                  # Freqüència de la sinusoide
L = int(fm * T)                           # Nombre de mostres del senyal digital
Tm=1/fm                                   # Període de mostratge
t=Tm*np.arange(L)                         # Vector amb els valors de la variable temporal, de 0 a T
x3 = A * np.cos(2 * pi * fx * t)           # Senyal sinusoidal
sf.write('so_10000.wav', x3, fm)           # Escriptura del senyal a un fitxer en format wav
Tx=1/fx                                   # Període del senyal
Ls=int(fm*5*Tx)                           # Nombre de mostres corresponents a 5 períodes de la sinusoide
plt.figure(3)                             # Nova figura
plt.plot(t[0:Ls], x3[0:Ls])                # Representació del senyal en funció del temps
plt.xlabel('t en segons')                 # Etiqueta eix temporal
plt.title('5 periodes de la sinusoide')   # Títol del gràfic
#sd.play(x3, fm)                            # Reproducció d'àudio
plt.savefig('img/sinusoide_10kHz.png')    # Escriptura de la gràfica del senyal en un fitxer png
plt.show()

# %% [markdown]
# ## 15 kHz

# %%
fm=300000                                 # Freqüència de mostratge en Hz
fx=15000                                  # Freqüència de la sinusoide
L = int(fm * T)                           # Nombre de mostres del senyal digital
Tm=1/fm                                   # Període de mostratge
t=Tm*np.arange(L)                         # Vector amb els valors de la variable temporal, de 0 a T
x4 = A * np.cos(2 * pi * fx * t)          # Senyal sinusoidal
sf.write('so_15000.wav', x4, fm)          # Escriptura del senyal a un fitxer en format wav
Tx=1/fx                                   # Període del senyal
Ls=int(fm*5*Tx)                           # Nombre de mostres corresponents a 5 períodes de la sinusoide
plt.figure(4)                             # Nova figura
plt.plot(t[0:Ls], x4[0:Ls])               # Representació del senyal en funció del temps
plt.xlabel('t en segons')                 # Etiqueta eix temporal
plt.title('5 periodes de la sinusoide')   # Títol del gràfic
#sd.play(x4, fm)                           # Reproducció d'àudio
plt.savefig('img/sinusoide_15kHz.png')    # Escriptura de la gràfica del senyal en un fitxer png
plt.show()

# %% [markdown]
# ## 18 kHz

# %%
fm=350000                                 # Freqüència de mostratge en Hz
fx=18000                                  # Freqüència de la sinusoide
L = int(fm * T)                           # Nombre de mostres del senyal digital
Tm=1/fm                                   # Període de mostratge
t=Tm*np.arange(L)                         # Vector amb els valors de la variable temporal, de 0 a T
x5 = A * np.cos(2 * pi * fx * t)          # Senyal sinusoidal
sf.write('so_18000.wav', x5, fm)          # Escriptura del senyal a un fitxer en format wav
Tx=1/fx                                   # Període del senyal
Ls=int(fm*5*Tx)                           # Nombre de mostres corresponents a 5 períodes de la sinusoide
plt.figure(5)                             # Nova figura
plt.plot(t[0:Ls], x5[0:Ls])               # Representació del senyal en funció del temps
plt.xlabel('t en segons')                 # Etiqueta eix temporal
plt.title('5 periodes de la sinusoide')   # Títol del gràfic
#sd.play(x5, fm)                           # Reproducció d'àudio
plt.savefig('img/sinusoide_18kHz.png')    # Escriptura de la gràfica del senyal en un fitxer png
plt.show()

# %% [markdown]
# 20 kHz
# ===

# %%
fm=350000                                 # Freqüència de mostratge en Hz
fx=20000                                  # Freqüència de la sinusoide
L = int(fm * T)                           # Nombre de mostres del senyal digital
Tm=1/fm                                   # Període de mostratge
t=Tm*np.arange(L)                         # Vector amb els valors de la variable temporal, de 0 a T
x6 = A * np.cos(2 * pi * fx * t)           # Senyal sinusoidal
sf.write('so_20000.wav', x6, fm)           # Escriptura del senyal a un fitxer en format wav
Tx=1/fx                                   # Període del senyal
Ls=int(fm*5*Tx)                           # Nombre de mostres corresponents a 5 períodes de la sinusoide
plt.figure(6)                             # Nova figura
plt.plot(t[0:Ls], x6[0:Ls])                # Representació del senyal en funció del temps
plt.xlabel('t en segons')                 # Etiqueta eix temporal
plt.title('5 periodes de la sinusoide')   # Títol del gràfic
#sd.play(x6, fm)                            # Reproducció d'àudio
plt.savefig('img/sinusoide_20kHz.png')    # Escriptura de la gràfica del senyal en un fitxer png
plt.show()

# %% [markdown]
# # Apartado 2

# %%
fm = 9000
L = int(fm * T)
t = Tm*np.arange(L)
x_r, fm = sf.read('wav/so_4000.wav')
fx = 4000
Tx = 1/fx
Ls = int(fm*5*Tx)

plt.figure(7)
plt.ylim(bottom = -2, top = 2)
plt.plot(t[:Ls], x_r[:Ls])                
plt.xlabel('t en segons')                 
plt.title('5 periodes de la sinusoide')
plt.savefig('img/sinusoide_4kHz_remostrejada.png')
plt.show()

N = 5000
x_fft=fft(x_r[:Ls], N)

k = np.arange(N)
plt.figure(8)
plt.subplot(211)
plt.plot(k, abs(x_fft))
plt.title(f'Tranformada de Fourier')
plt.ylabel('|X[k]|')
plt.subplot(212)
plt.plot(k, np.unwrap(np.angle(x_fft)))
plt.xlabel('Index k')
plt.ylabel('$\phi_x[k]$')
plt.savefig('img/TF_sinusoide_4kHz_remostrejada.png')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## APARTAT 3

# %%
T= 2.5 
fm = 6000
fz = 50                                                 # Frequencia del senyal
A = 4
L = int(fm * T)
pi = np.pi
Tm = 1 / fm
t = Tm * np.arange(L)
x_r = A * np.cos(2 * pi * f * t)                        # Senyal sinusoidal ex1
sf.write('so_ex1_50.wav', x_r, fm)                      # Creem un archiu a frequencia 50

Tz = 1 / fz
Ls = int(fm * 5 * Tz)

N = 50000
x_fft=fft(x_r[:Ls], N)
k = np.arange(N)
XdB = 20*np.log10(np.abs(x_fft) / max(np.abs(x_fft)))
fk = (k / N)*fm
plt.figure(9)
plt.title(f'Transformada del senyal de Ls={Ls} mostres amb DFT de N={N}')
plt.ylabel("|X[k]|(dB's)")
plt.plot(fk[0:int(fm/2)], XdB[0:int(fm/2)]) 
plt.xlabel('Hz')
plt.savefig('img/sinusoide_6KHz_YdB_XHz_.png')
plt.show()
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Apartat 4

# %%
s, fm = sf.read('wav/Wicked Game.wav')
nMostres = len(s)
print('Freqüència de mostratge (Hz): ', fm)
print('Nombre de mostres: ', nMostres)
# Out:
# Freqüència de mostratge (Hz):  44100
# Nombre de mostres:  12651408

# %%
s, fm = sf.read('wav/Wicked Game.wav')
t0 = 30                 # Inici del segment
tt = 0.025              # Durada del segment
L1 = int(fm * t0)
L2 = int(fm * (t0 + tt))

Tm = 1 / fm
t = Tm * np.arange(L1,L2)
plt.figure(10)
plt.plot(t, s[L1:L2])
plt.savefig('img/Segment_25ms_Wicked_Game.png')
plt.show()

# %%
s, fm = sf.read('wav/Wicked Game.wav')
t0 = 30                 # Inici del segment
tt = 0.025              # Durada del segment
L1 = int(fm * t0)
L2 = int(fm * (t0 + tt))

N=fm
S=fft(s[L1:L2], N)       
S_dB = 20*np.log10(np.abs(S)/max(np.abs(S)))
k=np.arange(N)                        # Vector amb els valors 0≤  k<N
fk =(k/N)*fm
plt.figure(10)                         # Nova figura          
plt.plot(fk[0:int(fm/2)], S_dB[0:int(fm/2)])          # Representació del mòdul de la transformada
plt.title(f'Transformada del senyal de Ls={L2-L1} mostres amb DFT de N={N}')   # Etiqueta del títol
plt.ylabel('|S[k]|(dB)')                  # Etiqueta de mòdul
plt.xlabel('Hz')                  # Etiqueta de mòdul
plt.savefig('img/Transformada_Segment_25ms_Wicked_Game.png')
plt.show()
